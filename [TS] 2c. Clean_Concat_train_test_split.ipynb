# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()
pd.set_option('display.max_columns', 60)
from sklearn.model_selection import train_test_split

# %%
df = pd.read_pickle('/content/drive/MyDrive/QE/Study2/TruthSeeker2023/truth_seeker_NER_emotion_stance.h5',compression='xz')

# %%
reverse_emotion_mapping = {'0':'anger',
                  '1':'fear',
                  '2':'disgust',
                  '3':'sadness',
                  '4':'neutral',
                  '5':'surprise',
                  '6':'joy',
                  'Con':'neutral',
                  'IV':'neutral',
                  'gross':'neutral',
                  '16':'neutral',
                  'gasp':'neutral',
                  'A':'neutral',
                  'dumb':'neutral',
                  'irony':'neutral',
                  'gasps':'neutral'

}

df['emotion'] = df['flan_emotion_pred'].map(reverse_emotion_mapping)
df['emotion'] = df['emotion'].fillna('neutral')

# %%
df.emotion.value_counts(dropna=False)
# Out:
# emotion
# neutral     261191
# anger        11824
# disgust       8832
# sadness       5066
# joy           4036
# fear          1646
# surprise      1280
# Name: count, dtype: int64

# %%
df.stance.value_counts(dropna=False)
# Out:
# stance
# NEUTRAL    156921
# AGAINST    126706
# FAVOR       10248
# Name: count, dtype: int64

# %%
def concat_aspect_emotion(data):
    descriptions = []

    for entry in data:
        target = entry['target']
        stance = entry['stance']
        emotion = entry['emotion']

        # Describe the aspect (target), stance, and emotion
        description = f"{emotion} emotion towards {target}"
        descriptions.append(description)

    joined_descriptions = ';'.join(descriptions)

    return joined_descriptions

def concat_aspect_stance(data):
    descriptions = []

    for entry in data:
        target = entry['target']
        stance = entry['stance']
        emotion = entry['emotion']

        # Describe the aspect (target), stance, and emotion
        description = f"{stance} stance towards {target}"
        descriptions.append(description)

    joined_descriptions = ';'.join(descriptions)

    return joined_descriptions

def concat_aspect_emotion_stance(data):
    descriptions = []

    for entry in data:
        target = entry['target']
        stance = entry['stance']  # Convert stance to lowercase
        emotion = entry['emotion'] # Convert emotion to lowercase

        # Describe the aspect (target), stance, and emotion
        description = f"{emotion} emotion & {stance} stance towards {target}"
        descriptions.append(description)

    joined_descriptions = ';'.join(descriptions)

    return joined_descriptions

# %%
df.columns
# Out:
# Index(['author', 'statement', 'BinaryNumTarget', 'tweet', 'timestamp',
#        'PARENT_ID', 'TWEET_ID', 'NER', 'target_type', 'target',
#        'target_filter', 'source_text', 'flan_emotion_pred', 'emotion',
#        'flan_stance', 'stance'],
#       dtype='object')

# %%
df['stance_emotion'] = df['stance'].astype(str) + '_' + df['emotion'].astype(str)

import re

#filter out targets that are just urls or emojis
def remove_urls(text):
    # Remove URLs using regular expression
    url_pattern = re.compile(r'https?://\S+|www\.\S+')
    text = url_pattern.sub('', text)

    text = re.sub(r'[^@a-zA-Z0-9_\s.,;:!?()-]', '', text)

    return text

df['target_len'] = df['target'].apply(lambda x: len(x))
df['target'] =  df['target'].apply(lambda x: remove_urls(x).strip())
df[(df['target'] != '')&(df['target_len'] >1)].target.value_counts()

df['text'] =  df.tweet
df['label'] =  df.BinaryNumTarget.apply(lambda x: int(x))
df
# Out:
#                 author                                          statement  \
# 0        Jon Greenberg  Says Donald Trump has "changed his mind" on ab...
# 1        Jon Greenberg  Says Donald Trump has "changed his mind" on ab...
# 2       Lauren Carroll  Says Donald Trump "supports eminent domain" an...
# 3       Lauren Carroll  Says Donald Trump "supports eminent domain" an...
# 4       Lauren Carroll  Says Donald Trump "supports eminent domain" an...
# ...                ...                                                ...
# 293870     Sean Gorman  Says President Barack Obama "will not utter th...
# 293871        Sue Owen  "Texas has the highest rate of uninsured in th...
# 293872   Jon Greenberg  Says President Barack Obama spied on my campai...
# 293873   Jon Greenberg  Says President Barack Obama spied on my campai...
# 293874   Jon Greenberg  Says his policy is that health insurance shoul...
#
#         BinaryNumTarget                                              tweet  \
# 0                   1.0  Says Donald Trump has "changed his mind" on ab...
# 1                   1.0  @realDonaldTrump donald trump  I so wanted to ...
# 2                   1.0  @hilljobee Ah, so eminent domain that Trump su...
# 3                   1.0  @hilljobee Ah, so eminent domain that Trump su...
# 4                   1.0  @hilljobee Ah, so eminent domain that Trump su...
# ...                 ...                                                ...
# 293870              1.0  Remember when Republicans hammered Obama becau...
# 293871              1.0  @JohnCornyn Texas has the highest rate of unin...
# 293872              0.0  Corrupt Joe Biden and Obama, who spied on my c...
# 293873              0.0  Corrupt Joe Biden and Obama, who spied on my c...
# 293874              0.0  @smiley_face50 @Tracy_Creates @JoeBiden Yes it...
#
#                              timestamp  PARENT_ID  TWEET_ID  \
# 0       Fri Apr 01 00:28:51 +0000 2016        358       358
# 1       Fri Apr 01 00:28:51 +0000 2016        358     45030
# 2       Fri Apr 01 00:52:15 +0000 2016        341     42068
# 3       Fri Apr 01 00:52:15 +0000 2016        341     42068
# 4       Fri Apr 01 00:52:15 +0000 2016        341     42068
# ...                                ...        ...       ...
# 293870  Wed Sep 30 23:16:49 +0000 2020        330     39776
# 293871  Wed Sep 30 23:44:29 +0000 2020        539     70635
# 293872  Wed Sep 30 23:55:01 +0000 2020        988    125850
# 293873  Wed Sep 30 23:55:01 +0000 2020        988    125850
# 293874  Wed Sep 30 23:57:36 +0000 2020        969    122357
#
#                                               NER target_type  \
# 0                          (Donald Trump, PERSON)      PERSON
# 1       (@realDonaldTrump donald trump  , PERSON)      PERSON
# 2                                 (Trump, PERSON)      PERSON
# 3                                (Heller, PERSON)      PERSON
# 4                                  (Cruz, PERSON)      PERSON
# ...                                           ...         ...
# 293870                            (Trump, PERSON)      PERSON
# 293871                               (Texas, GPE)         GPE
# 293872                        (Joe Biden, PERSON)      PERSON
# 293873                            (Obama, PERSON)      PERSON
# 293874                                        NaN
#
#                                target  target_filter  \
# 0                        Donald Trump           True
# 1       @realDonaldTrump donald trump           True
# 2                               Trump           True
# 3                              Heller           True
# 4                                Cruz           True
# ...                               ...            ...
# 293870                          Trump           True
# 293871                          Texas           True
# 293872                      Joe Biden           True
# 293873                          Obama           True
# 293874                                          True
#
#                                               source_text flan_emotion_pred  \
# 0       Classify stance towards the target:Donald Trum...                 4
# 1       Classify stance towards the target:@realDonald...                 4
# 2       Classify stance towards the target:Trump in th...                 4
# 3       Classify stance towards the target:Heller in t...                 4
# 4       Classify stance towards the target:Cruz in the...                 4
# ...                                                   ...               ...
# 293870  Classify stance towards the target:Trump in th...                 4
# 293871  Classify stance towards the target:Texas in th...                 4
# 293872  Classify stance towards the target:Joe Biden i...                 4
# 293873  Classify stance towards the target:Obama in th...                 4
# 293874  Classify stance towards the target: in the tex...                 4
#
#         emotion flan_stance   stance   stance_emotion  target_len  \
# 0       neutral           0  AGAINST  AGAINST_neutral          12
# 1       neutral           0  AGAINST  AGAINST_neutral          31
# 2       neutral           0  AGAINST  AGAINST_neutral           5
# 3       neutral           0  AGAINST  AGAINST_neutral           6
# 4       neutral           1  NEUTRAL  NEUTRAL_neutral           4
# ...         ...         ...      ...              ...         ...
# 293870  neutral           0  AGAINST  AGAINST_neutral           5
# 293871  neutral           0  AGAINST  AGAINST_neutral           5
# 293872  neutral           0  AGAINST  AGAINST_neutral           9
# 293873  neutral           0  AGAINST  AGAINST_neutral           5
# 293874  neutral           1  NEUTRAL  NEUTRAL_neutral           0
#
#                                                      text  label
# 0       Says Donald Trump has "changed his mind" on ab...      1
# 1       @realDonaldTrump donald trump  I so wanted to ...      1
# 2       @hilljobee Ah, so eminent domain that Trump su...      1
# 3       @hilljobee Ah, so eminent domain that Trump su...      1
# 4       @hilljobee Ah, so eminent domain that Trump su...      1
# ...                                                   ...    ...
# 293870  Remember when Republicans hammered Obama becau...      1
# 293871  @JohnCornyn Texas has the highest rate of unin...      1
# 293872  Corrupt Joe Biden and Obama, who spied on my c...      0
# 293873  Corrupt Joe Biden and Obama, who spied on my c...      0
# 293874  @smiley_face50 @Tracy_Creates @JoeBiden Yes it...      0
#
# [293875 rows x 20 columns]

# %%
def group_targets(data):
  df  = data
  # Fill NaN values in the 'target' column with an empty string
  df['target'] = df['target'].fillna('')

  df['dict_target_emotion_stance'] = df.apply(lambda row: {'target': row['target'], 'emotion': row['emotion'], 'stance': row['stance']}, axis=1)

  new_df = []

  for txt in tqdm(df.TWEET_ID.unique()):
    _df = df[df.TWEET_ID == txt]
    entries = _df['dict_target_emotion_stance'].tolist()

    _df = {'text':_df.text.tolist()[0],
          'label':_df.label.tolist()[0],
          #'src':_df.src.tolist()[0],
           #'tweet_user': _df.tweet_user.tolist()[0],
           'tweet_id':  _df.TWEET_ID.tolist()[0],
           #'depth':_df.depth.tolist()[0],
           #'parent_user':_df.parent_user.tolist()[0],
           'create_date':_df.timestamp.tolist()[0],
           'parent_id':_df.PARENT_ID.tolist()[0],

          'dict_target_emotion_stance':entries}
    new_df.append(_df)

  df = pd.DataFrame(new_df)
  # Function to filter rows based on the criteria
  def process_target_list(target_list):
      if len(target_list) > 1:
          # Keep only one dictionary if length is greater than 1
          non_empty_targets = [entry for entry in target_list if entry['target'] != '']
          return non_empty_targets
      else:
          # If length is 1, do nothing
          return target_list
  df['dict_target_emotion_stance'] = df['dict_target_emotion_stance'].apply(process_target_list)


  df['target_emotion_stance'] = df['dict_target_emotion_stance'].apply(lambda x: concat_aspect_emotion_stance(x))
  df['target_emotion'] = df['dict_target_emotion_stance'].apply(lambda x: concat_aspect_emotion(x))
  df['target_stance'] = df['dict_target_emotion_stance'].apply(lambda x: concat_aspect_stance(x))
  return df



# Apply the filtering function to the DataFrame
df2 = group_targets(df)
df2
# Out:
# 100%|██████████| 122786/122786 [02:32<00:00, 803.39it/s]
#                                                      text  label  tweet_id  \
# 0       Says Donald Trump has "changed his mind" on ab...      1       358
# 1       @realDonaldTrump donald trump  I so wanted to ...      1     45030
# 2       @hilljobee Ah, so eminent domain that Trump su...      1     42068
# 3       Says Donald Trump "supports eminent domain" an...      1       341
# 4        Paid family leave for New York kicks in in 2018.      1     16026
# ...                                                   ...    ...       ...
# 122781  @Kokomothegreat TWO VOTES PER PRECINCT....I HA...      1      6642
# 122782  Remember when Republicans hammered Obama becau...      1     39776
# 122783  @JohnCornyn Texas has the highest rate of unin...      1     70635
# 122784  Corrupt Joe Biden and Obama, who spied on my c...      0    125850
# 122785  @smiley_face50 @Tracy_Creates @JoeBiden Yes it...      0    122357
#
#                            create_date  parent_id  \
# 0       Fri Apr 01 00:28:51 +0000 2016        358
# 1       Fri Apr 01 00:28:51 +0000 2016        358
# 2       Fri Apr 01 00:52:15 +0000 2016        341
# 3       Fri Apr 01 00:52:15 +0000 2016        341
# 4       Fri Apr 01 01:36:18 +0000 2016        122
# ...                                ...        ...
# 122781  Wed Sep 30 23:16:07 +0000 2020         26
# 122782  Wed Sep 30 23:16:49 +0000 2020        330
# 122783  Wed Sep 30 23:44:29 +0000 2020        539
# 122784  Wed Sep 30 23:55:01 +0000 2020        988
# 122785  Wed Sep 30 23:57:36 +0000 2020        969
#
#                                dict_target_emotion_stance  \
# 0       [{'target': 'Donald Trump', 'emotion': 'neutra...
# 1       [{'target': '@realDonaldTrump donald trump', '...
# 2       [{'target': 'Trump', 'emotion': 'neutral', 'st...
# 3       [{'target': 'Donald Trump', 'emotion': 'neutra...
# 4       [{'target': 'New York', 'emotion': 'neutral', ...
# ...                                                   ...
# 122781  [{'target': 'TWEETS', 'emotion': 'neutral', 's...
# 122782  [{'target': 'Obama', 'emotion': 'neutral', 'st...
# 122783  [{'target': 'Texas', 'emotion': 'neutral', 'st...
# 122784  [{'target': 'Joe Biden', 'emotion': 'neutral',...
# 122785  [{'target': '', 'emotion': 'neutral', 'stance'...
#
#                                     target_emotion_stance  \
# 0       neutral emotion & AGAINST stance towards Donal...
# 1       neutral emotion & AGAINST stance towards @real...
# 2       neutral emotion & AGAINST stance towards Trump...
# 3       neutral emotion & NEUTRAL stance towards Donal...
# 4       neutral emotion & NEUTRAL stance towards New York
# ...                                                   ...
# 122781    neutral emotion & NEUTRAL stance towards TWEETS
# 122782  neutral emotion & AGAINST stance towards Obama...
# 122783     neutral emotion & AGAINST stance towards Texas
# 122784  neutral emotion & AGAINST stance towards Joe B...
# 122785          neutral emotion & NEUTRAL stance towards
#
#                                            target_emotion  \
# 0                    neutral emotion towards Donald Trump
# 1       neutral emotion towards @realDonaldTrump donal...
# 2       neutral emotion towards Trump;neutral emotion ...
# 3       neutral emotion towards Donald Trump;neutral e...
# 4                        neutral emotion towards New York
# ...                                                   ...
# 122781                     neutral emotion towards TWEETS
# 122782  neutral emotion towards Obama;neutral emotion ...
# 122783                      neutral emotion towards Texas
# 122784  neutral emotion towards Joe Biden;neutral emot...
# 122785                           neutral emotion towards
#
#                                             target_stance
# 0                     AGAINST stance towards Donald Trump
# 1       AGAINST stance towards @realDonaldTrump donald...
# 2       AGAINST stance towards Trump;AGAINST stance to...
# 3       NEUTRAL stance towards Donald Trump;NEUTRAL st...
# 4                         NEUTRAL stance towards New York
# ...                                                   ...
# 122781                      NEUTRAL stance towards TWEETS
# 122782  AGAINST stance towards Obama;AGAINST stance to...
# 122783                       AGAINST stance towards Texas
# 122784  AGAINST stance towards Joe Biden;AGAINST stanc...
# 122785                            NEUTRAL stance towards
#
# [122786 rows x 9 columns]

# %%
'''removing duplicate targets'''
def collapse_duplicates(data):
    # Iterate through each row
    for i in tqdm(range(len(data))):
        # Get the list of dictionaries for the current row
        entries = data[i]

        # Use a set to keep track of unique entries
        unique_entries = set()

        # Create a new list to store the non-duplicate dictionaries
        unique_list = []

        try:
          # Iterate through each dictionary in the original list
          for entry in entries:
              # Convert the dictionary to a tuple and check for uniqueness
              entry_tuple = tuple(entry.items())

              # Check if the current entry is unique
              if entry_tuple not in unique_entries:
                  unique_entries.add(entry_tuple)
                  unique_list.append(entry)

          # Update the 'dict_target_emotion_stance' column with the new list
          data[i] = unique_list
        except AttributeError:
          data[i] = entries
        except TypeError:
          data[i] = entries

    return data

# Example usage with your DataFrame
df2['dict_target_emotion_stance'] = collapse_duplicates(df2['dict_target_emotion_stance'])
# Out:
# Streaming output truncated to the last 5000 lines.
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
#  99%|█████████▉| 121817/122786 [02:20<00:01, 698.08it/s]<ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
#  99%|█████████▉| 121919/122786 [02:20<00:01, 781.02it/s]<ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# 100%|█████████▉| 122744/122786 [02:21<00:00, 967.59it/s]<ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# <ipython-input-11-4bb85bc02ea5>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[i] = unique_list
# 100%|██████████| 122786/122786 [02:21<00:00, 866.71it/s]

# %%
df2.sort_values(by='create_date', inplace=True)

# %%
df2
# Out:
#                                                      text  label  tweet_id  \
# 0       Says Donald Trump has "changed his mind" on ab...      1       358
# 1       @realDonaldTrump donald trump  I so wanted to ...      1     45030
# 2       @hilljobee Ah, so eminent domain that Trump su...      1     42068
# 3       Says Donald Trump "supports eminent domain" an...      1       341
# 4        Paid family leave for New York kicks in in 2018.      1     16026
# ...                                                   ...    ...       ...
# 122781  @Kokomothegreat TWO VOTES PER PRECINCT....I HA...      1      6642
# 122782  Remember when Republicans hammered Obama becau...      1     39776
# 122783  @JohnCornyn Texas has the highest rate of unin...      1     70635
# 122784  Corrupt Joe Biden and Obama, who spied on my c...      0    125850
# 122785  @smiley_face50 @Tracy_Creates @JoeBiden Yes it...      0    122357
#
#                            create_date  parent_id  \
# 0       Fri Apr 01 00:28:51 +0000 2016        358
# 1       Fri Apr 01 00:28:51 +0000 2016        358
# 2       Fri Apr 01 00:52:15 +0000 2016        341
# 3       Fri Apr 01 00:52:15 +0000 2016        341
# 4       Fri Apr 01 01:36:18 +0000 2016        122
# ...                                ...        ...
# 122781  Wed Sep 30 23:16:07 +0000 2020         26
# 122782  Wed Sep 30 23:16:49 +0000 2020        330
# 122783  Wed Sep 30 23:44:29 +0000 2020        539
# 122784  Wed Sep 30 23:55:01 +0000 2020        988
# 122785  Wed Sep 30 23:57:36 +0000 2020        969
#
#                                dict_target_emotion_stance  \
# 0       [{'target': 'Donald Trump', 'emotion': 'neutra...
# 1       [{'target': '@realDonaldTrump donald trump', '...
# 2       [{'target': 'Trump', 'emotion': 'neutral', 'st...
# 3       [{'target': 'Donald Trump', 'emotion': 'neutra...
# 4       [{'target': 'New York', 'emotion': 'neutral', ...
# ...                                                   ...
# 122781  [{'target': 'TWEETS', 'emotion': 'neutral', 's...
# 122782  [{'target': 'Obama', 'emotion': 'neutral', 'st...
# 122783  [{'target': 'Texas', 'emotion': 'neutral', 'st...
# 122784  [{'target': 'Joe Biden', 'emotion': 'neutral',...
# 122785  [{'target': '', 'emotion': 'neutral', 'stance'...
#
#                                     target_emotion_stance  \
# 0       neutral emotion & AGAINST stance towards Donal...
# 1       neutral emotion & AGAINST stance towards @real...
# 2       neutral emotion & AGAINST stance towards Trump...
# 3       neutral emotion & NEUTRAL stance towards Donal...
# 4       neutral emotion & NEUTRAL stance towards New York
# ...                                                   ...
# 122781    neutral emotion & NEUTRAL stance towards TWEETS
# 122782  neutral emotion & AGAINST stance towards Obama...
# 122783     neutral emotion & AGAINST stance towards Texas
# 122784  neutral emotion & AGAINST stance towards Joe B...
# 122785          neutral emotion & NEUTRAL stance towards
#
#                                            target_emotion  \
# 0                    neutral emotion towards Donald Trump
# 1       neutral emotion towards @realDonaldTrump donal...
# 2       neutral emotion towards Trump;neutral emotion ...
# 3       neutral emotion towards Donald Trump;neutral e...
# 4                        neutral emotion towards New York
# ...                                                   ...
# 122781                     neutral emotion towards TWEETS
# 122782  neutral emotion towards Obama;neutral emotion ...
# 122783                      neutral emotion towards Texas
# 122784  neutral emotion towards Joe Biden;neutral emot...
# 122785                           neutral emotion towards
#
#                                             target_stance
# 0                     AGAINST stance towards Donald Trump
# 1       AGAINST stance towards @realDonaldTrump donald...
# 2       AGAINST stance towards Trump;AGAINST stance to...
# 3       NEUTRAL stance towards Donald Trump;NEUTRAL st...
# 4                         NEUTRAL stance towards New York
# ...                                                   ...
# 122781                      NEUTRAL stance towards TWEETS
# 122782  AGAINST stance towards Obama;AGAINST stance to...
# 122783                       AGAINST stance towards Texas
# 122784  AGAINST stance towards Joe Biden;AGAINST stanc...
# 122785                            NEUTRAL stance towards
#
# [122786 rows x 9 columns]

# %%
_df = pd.read_excel('/content/drive/MyDrive/QE/Study2/TruthSeeker2023/Truth_Seeker_Model_Dataset_With_TimeStamps 1.xlsx')
_df.BinaryNumTarget.value_counts(dropna=False)
# Out:
# BinaryNumTarget
# 1.0    68930
# 0.0    65268
# NaN        5
# Name: count, dtype: int64

# %%
_df[_df.BinaryNumTarget.isna()]
# Out:
#                                               Unnamed: 0    author  \
# 22779  Trump admin hypocritical on States' Rights vis...     Agree
# 33370  Our New Hampshire poll is finding real anger t...     Agree
# 83724                         because of gun control: 56       NaN
# 83725                                           million.  Disagree
# 93242                                          #FLDebate     Agree
#
#                             statement  target  BinaryNumTarget  \
# 22779  Mon Feb 27 17:12:53 +0000 2017     NaN              NaN
# 33370  Sun Apr 21 16:34:25 +0000 2013     NaN              NaN
# 83724                             NaN     NaN              NaN
# 83725  Mon Sep 21 01:21:40 +0000 2009     NaN              NaN
# 93242  Tue Jan 24 03:14:34 +0000 2012     NaN              NaN
#
#       manual_keywords tweet 5_label_majority_answer 3_label_majority_answer  \
# 22779             NaN   NaN                     NaN                     NaN
# 33370             NaN   NaN                     NaN                     NaN
# 83724             NaN   NaN                     NaN                     NaN
# 83725             NaN   NaN                     NaN                     NaN
# 93242             NaN   NaN                     NaN                     NaN
#
#       timestamp
# 22779       NaN
# 33370       NaN
# 83724       NaN
# 83725       NaN
# 93242       NaN

# %%
_df.iloc[93241:93243]
# Out:
#       Unnamed: 0      author  \
# 93241      93237  W. Gardner
# 93242  #FLDebate       Agree
#
#                                                statement  target  \
# 93241  Says Barack Obama has played over 90 rounds of...     1.0
# 93242                     Tue Jan 24 03:14:34 +0000 2012     NaN
#
#        BinaryNumTarget           manual_keywords  \
# 93241              1.0  Obama, 90 rounds of golf
# 93242              NaN                       NaN
#
#                                                    tweet  \
# 93241  RT @GOPrincess: Romney:  Obama plays 90 rounds...
# 93242                                                NaN
#
#       5_label_majority_answer 3_label_majority_answer timestamp
# 93241                     NaN                     NaN       NaN
# 93242                     NaN                     NaN       NaN

# %%
_df = pd.read_excel('/content/drive/MyDrive/QE/Study2/TruthSeeker2023/Truth_Seeker_Model_Dataset_With_TimeStamps 1.xlsx').dropna()
_df
# Out:
#        Unnamed: 0         author  \
# 0               0     D.L. Davis
# 1               1     D.L. Davis
# 2               2     D.L. Davis
# 3               3     D.L. Davis
# 4               4     D.L. Davis
# ...           ...            ...
# 134198     134193  Tom Kertscher
# 134199     134194  Tom Kertscher
# 134200     134195  Tom Kertscher
# 134201     134196  Tom Kertscher
# 134202     134197  Tom Kertscher
#
#                                                 statement  target  \
# 0       End of eviction moratorium means millions of A...     1.0
# 1       End of eviction moratorium means millions of A...     1.0
# 2       End of eviction moratorium means millions of A...     1.0
# 3       End of eviction moratorium means millions of A...     1.0
# 4       End of eviction moratorium means millions of A...     1.0
# ...                                                   ...     ...
# 134198  Joe Bidens great-grandfather Joseph J. Biden w...     0.0
# 134199  Joe Bidens great-grandfather Joseph J. Biden w...     0.0
# 134200  Joe Bidens great-grandfather Joseph J. Biden w...     0.0
# 134201  Joe Bidens great-grandfather Joseph J. Biden w...     0.0
# 134202  Joe Bidens great-grandfather Joseph J. Biden w...     0.0
#
#         BinaryNumTarget                        manual_keywords  \
# 0                   1.0         Americans, eviction moratorium
# 1                   1.0         Americans, eviction moratorium
# 2                   1.0         Americans, eviction moratorium
# 3                   1.0         Americans, eviction moratorium
# 4                   1.0         Americans, eviction moratorium
# ...                 ...                                    ...
# 134198              0.0  Biden, great grandfather, slave owner
# 134199              0.0  Biden, great grandfather, slave owner
# 134200              0.0  Biden, great grandfather, slave owner
# 134201              0.0  Biden, great grandfather, slave owner
# 134202              0.0  Biden, great grandfather, slave owner
#
#                                                     tweet  \
# 0       @POTUS Biden Blunders - 6 Month Update\n\nInfl...
# 1       @S0SickRick @Stairmaster_ @6d6f636869 Not as m...
# 2       THE SUPREME COURT is siding with super rich pr...
# 3       @POTUS Biden Blunders\n\nBroken campaign promi...
# 4       @OhComfy I agree. The confluence of events rig...
# ...                                                   ...
# 134198  Joe Biden's family owned African slaves....\n\...
# 134199  Joe Bidens great, great grandfather was a slav...
# 134200  @ChevyChaseToGo "Joe Bidens great-grandfather ...
# 134201  @JoeBiden Facts are Bidens VP Kamala Harris Gr...
# 134202  @sunny Yes representation matters. Did you kno...
#
#        5_label_majority_answer 3_label_majority_answer  \
# 0                 Mostly Agree                   Agree
# 1                  NO MAJORITY                   Agree
# 2                        Agree                   Agree
# 3                 Mostly Agree                   Agree
# 4                        Agree                   Agree
# ...                        ...                     ...
# 134198            Mostly Agree                   Agree
# 134199                   Agree                   Agree
# 134200            Mostly Agree                   Agree
# 134201             NO MAJORITY                   Agree
# 134202                   Agree                   Agree
#
#                              timestamp
# 0       Thu Sep 09 23:58:53 +0000 2021
# 1       Mon Aug 30 18:58:09 +0000 2021
# 2       Fri Aug 27 09:53:44 +0000 2021
# 3       Tue Oct 05 20:37:14 +0000 2021
# 4       Fri Aug 27 10:58:24 +0000 2021
# ...                                ...
# 134198  Mon Jun 22 15:02:31 +0000 2020
# 134199  Mon Oct 12 15:52:02 +0000 2020
# 134200  Fri Oct 16 21:02:49 +0000 2020
# 134201  Thu Jun 17 20:30:22 +0000 2021
# 134202  Tue Oct 13 01:40:49 +0000 2020
#
# [134193 rows x 10 columns]

# %%
_df.target.value_counts()
# Out:
# target
# 1.0    68926
# 0.0    65267
# Name: count, dtype: int64

# %%
_df = pd.read_excel('/content/drive/MyDrive/QE/Study2/TruthSeeker2023/Truth_Seeker_Model_Dataset_With_TimeStamps 1.xlsx').dropna()

# Creating unique identifiers for author-statement pairs
author_statement = _df['author'] + "|" + _df['statement']
_df['PARENT_ID'] = pd.factorize(author_statement)[0]

_df['PARENT_ID'] = _df['PARENT_ID'] + 1

# Calculate starting point for Tweet_IDs to avoid overlap
tweet_id_start = _df['PARENT_ID'].max() + 1

# Assign unique identifiers for tweets, handling NaN values and ensuring no overlap
_df['TWEET_ID'] = [i + tweet_id_start for i in range(len(_df))]
_df['root_node']= _df['PARENT_ID']

_df = _df[['author', 'statement', 'BinaryNumTarget', 'tweet', 'timestamp', 'PARENT_ID', 'TWEET_ID','root_node']]
display(_df)

_df['timestamp'] = pd.to_datetime(_df['timestamp'], format='%a %b %d %H:%M:%S %z %Y').dt.tz_localize(None)

#given that it is a star-like graph without retweets,
origin = _df[['author', 'statement',  'BinaryNumTarget', 'PARENT_ID']].drop_duplicates(['author','statement'])
origin['TWEET_ID']= origin['PARENT_ID']
origin['tweet']= origin['statement']

#here I will assume that the earliest timestamp for each PARENT_ID in the main DataFrame is the parentID time stamp
earliest_timestamps = _df.groupby('PARENT_ID')['timestamp'].min().reset_index()

# Merge the earliest timestamp with the origin DataFrame on PARENT_ID
origin = origin.merge(earliest_timestamps, on='PARENT_ID', how='left')
origin['root_node']= origin['PARENT_ID']
origin['PARENT_ID']= 0
origin

_df = pd.concat([_df, origin], ignore_index=True).drop_duplicates()
_df = _df.sort_values(by='timestamp')

_df['text'] = _df['tweet']
# Out:
#                author                                          statement  \
# 0          D.L. Davis  End of eviction moratorium means millions of A...
# 1          D.L. Davis  End of eviction moratorium means millions of A...
# 2          D.L. Davis  End of eviction moratorium means millions of A...
# 3          D.L. Davis  End of eviction moratorium means millions of A...
# 4          D.L. Davis  End of eviction moratorium means millions of A...
# ...               ...                                                ...
# 134198  Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
# 134199  Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
# 134200  Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
# 134201  Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
# 134202  Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
#
#         BinaryNumTarget                                              tweet  \
# 0                   1.0  @POTUS Biden Blunders - 6 Month Update\n\nInfl...
# 1                   1.0  @S0SickRick @Stairmaster_ @6d6f636869 Not as m...
# 2                   1.0  THE SUPREME COURT is siding with super rich pr...
# 3                   1.0  @POTUS Biden Blunders\n\nBroken campaign promi...
# 4                   1.0  @OhComfy I agree. The confluence of events rig...
# ...                 ...                                                ...
# 134198              0.0  Joe Biden's family owned African slaves....\n\...
# 134199              0.0  Joe Bidens great, great grandfather was a slav...
# 134200              0.0  @ChevyChaseToGo "Joe Bidens great-grandfather ...
# 134201              0.0  @JoeBiden Facts are Bidens VP Kamala Harris Gr...
# 134202              0.0  @sunny Yes representation matters. Did you kno...
#
#                              timestamp  PARENT_ID  TWEET_ID  root_node
# 0       Thu Sep 09 23:58:53 +0000 2021          1      1059          1
# 1       Mon Aug 30 18:58:09 +0000 2021          1      1060          1
# 2       Fri Aug 27 09:53:44 +0000 2021          1      1061          1
# 3       Tue Oct 05 20:37:14 +0000 2021          1      1062          1
# 4       Fri Aug 27 10:58:24 +0000 2021          1      1063          1
# ...                                ...        ...       ...        ...
# 134198  Mon Jun 22 15:02:31 +0000 2020       1058    135247       1058
# 134199  Mon Oct 12 15:52:02 +0000 2020       1058    135248       1058
# 134200  Fri Oct 16 21:02:49 +0000 2020       1058    135249       1058
# 134201  Thu Jun 17 20:30:22 +0000 2021       1058    135250       1058
# 134202  Tue Oct 13 01:40:49 +0000 2020       1058    135251       1058
#
# [134193 rows x 8 columns]

# %%
earliest_timestamps
# Out:
#       PARENT_ID           timestamp
# 0             1 2021-08-03 01:02:45
# 1             2 2021-08-16 18:40:57
# 2             3 2009-06-06 02:26:50
# 3             4 2020-04-23 22:37:02
# 4             5 2020-01-05 18:20:26
# ...         ...                 ...
# 1053       1054 2020-06-26 18:54:55
# 1054       1055 2021-01-10 18:12:05
# 1055       1056 2020-05-21 20:55:57
# 1056       1057 2011-04-08 02:09:01
# 1057       1058 2019-07-02 12:17:31
#
# [1058 rows x 2 columns]

# %%
origin.BinaryNumTarget.value_counts()
# Out:
# BinaryNumTarget
# 1.0    579
# 0.0    479
# Name: count, dtype: int64

# %%
df3 = df2[['text','dict_target_emotion_stance','target_emotion_stance']]
df4 = pd.merge(_df,df3,on='text',how='left')
df4['parent_id'] = df4['PARENT_ID']
df4['tweet_id'] = df4['TWEET_ID']
df4['create_date'] = df4['timestamp']
df4['label'] = df4['BinaryNumTarget'].apply(lambda x: int(x))
df4 = df4.dropna()
df4
# Out:
#                  author                                          statement  \
# 2         Katie Sanders  Says Mike Huckabee appeared in diabetes infome...
# 3         Katie Sanders  Says Mike Huckabee appeared in diabetes infome...
# 4         Katie Sanders  Says Mike Huckabee appeared in diabetes infome...
# 7            W. Gardner  "The majority of Austinites rent" the places t...
# 9         Mica Soellner  "The law says that mental health must be treat...
# ...                 ...                                                ...
# 135246  Patrick Orsagos  The United Nations new world order agenda will...
# 135247   Ciara O'Rourke                    Herd immunity has been reached.
# 135248  Patrick Orsagos  The United Nations new world order agenda will...
# 135249  Patrick Orsagos  The United Nations new world order agenda will...
# 135250   Louis Jacobson  Biden invested the entire family fortune in Uk...
#
#         BinaryNumTarget                                              tweet  \
# 2                   1.0  Says Mike Huckabee appeared in diabetes infome...
# 3                   1.0  I might get an interview with Mike Huckabee ab...
# 4                   1.0  @dporter THANKS! I may get to interview Mike H...
# 7                   1.0  austinites - we're coming to austin at the end...
# 9                   1.0  pages upon pages of provision to require insur...
# ...                 ...                                                ...
# 135246              0.0  Countries should be wanting to leave the Unite...
# 135247              0.0  @ragedcan @LBJ20Trey @duncTTV @KDTreeey5 @TheN...
# 135248              0.0  ... avoided, and prevented, and you spare the ...
# 135249              0.0  ... control. \n\nAt that point, KNOW AND UNDER...
# 135250              0.0  @montrealer97 @deette_hankins @phildstewart Wo...
#
#                  timestamp  PARENT_ID  TWEET_ID  root_node  \
# 2      2008-05-05 15:20:48          0       378        378
# 3      2008-05-05 15:20:48        378     46516        378
# 4      2008-05-06 12:27:06        378     46541        378
# 7      2008-09-18 17:06:07        498     61417        498
# 9      2008-10-01 17:11:31         88     13397         88
# ...                    ...        ...       ...        ...
# 135246 2022-02-28 22:17:26       1033    133014       1033
# 135247 2022-02-28 22:22:27       1005    127838       1005
# 135248 2022-02-28 22:32:47       1033    132719       1033
# 135249 2022-02-28 22:34:36       1033    133156       1033
# 135250 2022-03-01 02:00:52        801     99846        801
#
#                                                      text  \
# 2       Says Mike Huckabee appeared in diabetes infome...
# 3       I might get an interview with Mike Huckabee ab...
# 4       @dporter THANKS! I may get to interview Mike H...
# 7       austinites - we're coming to austin at the end...
# 9       pages upon pages of provision to require insur...
# ...                                                   ...
# 135246  Countries should be wanting to leave the Unite...
# 135247  @ragedcan @LBJ20Trey @duncTTV @KDTreeey5 @TheN...
# 135248  ... avoided, and prevented, and you spare the ...
# 135249  ... control. \n\nAt that point, KNOW AND UNDER...
# 135250  @montrealer97 @deette_hankins @phildstewart Wo...
#
#                                dict_target_emotion_stance  \
# 2       [{'target': 'Mike Huckabee', 'emotion': 'neutr...
# 3       [{'target': 'Mike Huckabee', 'emotion': 'neutr...
# 4       [{'target': '@dporter', 'emotion': 'neutral', ...
# 7       [{'target': 'austin', 'emotion': 'neutral', 's...
# 9       [{'target': '', 'emotion': 'neutral', 'stance'...
# ...                                                   ...
# 135246  [{'target': 'the United Nations', 'emotion': '...
# 135247  [{'target': '@LBJ20Trey', 'emotion': 'anger', ...
# 135248  [{'target': 'the united nations', 'emotion': '...
# 135249  [{'target': 'the united nations', 'emotion': '...
# 135250  [{'target': 'Hunter Biden', 'emotion': 'neutra...
#
#                                     target_emotion_stance  parent_id  \
# 2       neutral emotion & AGAINST stance towards Mike ...          0
# 3       neutral emotion & FAVOR stance towards Mike Hu...        378
# 4       neutral emotion & FAVOR stance towards @dporte...        378
# 7         neutral emotion & NEUTRAL stance towards austin        498
# 9               neutral emotion & NEUTRAL stance towards          88
# ...                                                   ...        ...
# 135246  neutral emotion & AGAINST stance towards the U...       1033
# 135247  anger emotion & NEUTRAL stance towards @LBJ20T...       1005
# 135248  neutral emotion & AGAINST stance towards the u...       1033
# 135249  neutral emotion & AGAINST stance towards the u...       1033
# 135250  neutral emotion & AGAINST stance towards Hunte...        801
#
#         tweet_id         create_date  label
# 2            378 2008-05-05 15:20:48      1
# 3          46516 2008-05-05 15:20:48      1
# 4          46541 2008-05-06 12:27:06      1
# 7          61417 2008-09-18 17:06:07      1
# 9          13397 2008-10-01 17:11:31      1
# ...          ...                 ...    ...
# 135246    133014 2022-02-28 22:17:26      0
# 135247    127838 2022-02-28 22:22:27      0
# 135248    132719 2022-02-28 22:32:47      0
# 135249    133156 2022-02-28 22:34:36      0
# 135250     99846 2022-03-01 02:00:52      0
#
# [122804 rows x 15 columns]

# %%
df4.label.value_counts()
# Out:
# label
# 1    62150
# 0    60654
# Name: count, dtype: int64

# %%
df4.dropna().label.value_counts()
# Out:
# label
# 1    62150
# 0    60654
# Name: count, dtype: int64

# %%
root_nodes = list(set(df4[df4['parent_id'] == 0].root_node))

_df = []
for i in tqdm(range(len(root_nodes))):
    text_df_subset = df4[df4.root_node == root_nodes[i]].copy()
    root_time = text_df_subset[text_df_subset['parent_id'] == 0]['create_date']
    text_df_subset['time_elapsed'] = text_df_subset['create_date'].apply(lambda x: x - root_time.values[0])
    text_df_subset['time_elapsed'] = text_df_subset['time_elapsed'].dt.total_seconds() / 60
    text_df_subset['time_elapsed'] = text_df_subset['time_elapsed'].apply(lambda x: max(x, 0))
    _df.append(text_df_subset)
df4 = pd.concat(_df)
df4
# Out:
# 100%|██████████| 877/877 [00:06<00:00, 143.56it/s]
#                  author                                          statement  \
# 103844  Miriam Valverde  The Trump administration worked to free 5,000 ...
# 103845  Miriam Valverde  The Trump administration worked to free 5,000 ...
# 103851  Miriam Valverde  The Trump administration worked to free 5,000 ...
# 103852  Miriam Valverde  The Trump administration worked to free 5,000 ...
# 103855  Miriam Valverde  The Trump administration worked to free 5,000 ...
# ...                 ...                                                ...
# 99368     Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
# 113462    Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
# 129702    Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
# 129765    Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
# 131344    Tom Kertscher  Joe Bidens great-grandfather Joseph J. Biden w...
#
#         BinaryNumTarget                                              tweet  \
# 103844              1.0  @mikepompeo No Mike Pompeo you and the Trump A...
# 103845              1.0  The Trump administration worked to free 5,000 ...
# 103851              1.0  @danzu72 @chipfranklin I agree, but I would ad...
# 103852              1.0  @LindseyGrahamSC @FoxNews So you can lie about...
# 103855              1.0  @EliseStefanik A disgrace.\n\nWhy did the Trum...
# ...                 ...                                                ...
# 99368               0.0  @LionelMedia #Democrats want to bring back old...
# 113462              0.0  Did you know that one of Harris's Great Grandf...
# 129702              0.0  @ElieNYC Is the great granddaughter of freed s...
# 129765              0.0  @Federalist_10 @brianstelter @POTUS @SpeakerPe...
# 131344              0.0  @Rachael712A @Q_Estrada @drdeblk @SandraNotSan...
#
#                  timestamp  PARENT_ID  TWEET_ID  root_node  \
# 103844 2021-08-16 18:40:57          2      1720          2
# 103845 2021-08-16 18:40:57          0         2          2
# 103851 2021-08-16 19:08:49          2      1872          2
# 103852 2021-08-16 19:20:51          2      1571          2
# 103855 2021-08-16 19:26:28          2      1566          2
# ...                    ...        ...       ...        ...
# 99368  2021-07-18 10:53:02       1058    135197       1058
# 113462 2021-10-10 12:55:21       1058    135201       1058
# 129702 2022-01-14 20:21:52       1058    135215       1058
# 129765 2022-01-15 05:50:07       1058    135164       1058
# 131344 2022-01-25 08:14:35       1058    135202       1058
#
#                                                      text  \
# 103844  @mikepompeo No Mike Pompeo you and the Trump A...
# 103845  The Trump administration worked to free 5,000 ...
# 103851  @danzu72 @chipfranklin I agree, but I would ad...
# 103852  @LindseyGrahamSC @FoxNews So you can lie about...
# 103855  @EliseStefanik A disgrace.\n\nWhy did the Trum...
# ...                                                   ...
# 99368   @LionelMedia #Democrats want to bring back old...
# 113462  Did you know that one of Harris's Great Grandf...
# 129702  @ElieNYC Is the great granddaughter of freed s...
# 129765  @Federalist_10 @brianstelter @POTUS @SpeakerPe...
# 131344  @Rachael712A @Q_Estrada @drdeblk @SandraNotSan...
#
#                                dict_target_emotion_stance  \
# 103844  [{'target': 'Mike Pompeo', 'emotion': 'neutral...
# 103845  [{'target': 'Trump', 'emotion': 'neutral', 'st...
# 103851  [{'target': 'the Trump Administration', 'emoti...
# 103852  [{'target': '@LindseyGrahamSC @FoxNews', 'emot...
# 103855  [{'target': 'Trump Administration', 'emotion':...
# ...                                                   ...
# 99368   [{'target': 'Biden', 'emotion': 'neutral', 'st...
# 113462  [{'target': 'Harris', 'emotion': 'neutral', 's...
# 129702  [{'target': '@ElieNYC', 'emotion': 'neutral', ...
# 129765  [{'target': 'the White House', 'emotion': 'neu...
# 131344  [{'target': '@Q_Estrada @drdeblk @SandraNotSan...
#
#                                     target_emotion_stance  parent_id  \
# 103844  neutral emotion & AGAINST stance towards Mike ...          2
# 103845  neutral emotion & FAVOR stance towards Trump;n...          0
# 103851  neutral emotion & AGAINST stance towards the T...          2
# 103852  neutral emotion & NEUTRAL stance towards @Lind...          2
# 103855  neutral emotion & AGAINST stance towards Trump...          2
# ...                                                   ...        ...
# 99368   neutral emotion & AGAINST stance towards Biden...       1058
# 113462  neutral emotion & AGAINST stance towards Harri...       1058
# 129702  neutral emotion & NEUTRAL stance towards @Elie...       1058
# 129765  neutral emotion & NEUTRAL stance towards the W...       1058
# 131344  neutral emotion & NEUTRAL stance towards @Q_Es...       1058
#
#         tweet_id         create_date  label  time_elapsed
# 103844      1720 2021-08-16 18:40:57      1  0.000000e+00
# 103845         2 2021-08-16 18:40:57      1  0.000000e+00
# 103851      1872 2021-08-16 19:08:49      1  2.786667e+01
# 103852      1571 2021-08-16 19:20:51      1  3.990000e+01
# 103855      1566 2021-08-16 19:26:28      1  4.551667e+01
# ...          ...                 ...    ...           ...
# 99368     135197 2021-07-18 10:53:02      0  1.075596e+06
# 113462    135201 2021-10-10 12:55:21      0  1.196678e+06
# 129702    135215 2022-01-14 20:21:52      0  1.335364e+06
# 129765    135164 2022-01-15 05:50:07      0  1.335933e+06
# 131344    135202 2022-01-25 08:14:35      0  1.350477e+06
#
# [103672 rows x 16 columns]

# %%
df4[df4.parent_id==0].time_elapsed.value_counts()
# Out:
# time_elapsed
# 0.0    877
# Name: count, dtype: int64

# %%
df4[(df4.parent_id==0)&(df4.time_elapsed==34774.5)]
# Out:
#             author                                          statement  \
# 105839  D.L. Davis  End of eviction moratorium means millions of A...
#
#         BinaryNumTarget                                              tweet  \
# 105839              1.0  The Trump=elected United States Supreme Court ...
#
#                  timestamp  PARENT_ID  TWEET_ID  root_node  \
# 105839 2021-08-27 04:37:15          0      1445          0
#
#                                                      text  \
# 105839  The Trump=elected United States Supreme Court ...
#
#                                dict_target_emotion_stance  \
# 105839  [{'target': 'Trump', 'emotion': 'sadness', 'st...
#
#                                     target_emotion_stance  parent_id  \
# 105839  sadness emotion & NEUTRAL stance towards Trump...          0
#
#         tweet_id         create_date  label  time_elapsed
# 105839      1445 2021-08-27 04:37:15      1       34774.5

# %%
df4[(df4.parent_id==0)&(df4.time_elapsed==34774.5)]

# %%
df4[df4.root_node==0].sort_values('create_date')
# Out:
#             author                                          statement  \
# 101747  D.L. Davis  End of eviction moratorium means millions of A...
# 101748  D.L. Davis  End of eviction moratorium means millions of A...
# 101749  D.L. Davis  End of eviction moratorium means millions of A...
# 101754  D.L. Davis  End of eviction moratorium means millions of A...
# 101759  D.L. Davis  End of eviction moratorium means millions of A...
# ...            ...                                                ...
# 119477  D.L. Davis  End of eviction moratorium means millions of A...
# 119585  D.L. Davis  End of eviction moratorium means millions of A...
# 120413  D.L. Davis  End of eviction moratorium means millions of A...
# 120550  D.L. Davis  End of eviction moratorium means millions of A...
# 121441  D.L. Davis  End of eviction moratorium means millions of A...
#
#         BinaryNumTarget                                              tweet  \
# 101747              1.0  @CoriBush You are a leader. I just wanted to s...
# 101748              1.0  Why does @JoeBiden hate Americans? He wont act...
# 101749              1.0  @gregkellyusa @CoriBush She's sleeping on the ...
# 101754              1.0  @aplemkseriously @CoriBush @CoriBush knew July...
# 101759              1.0  @BillFOXLA @FoxNews I love how the only issue ...
# ...                 ...                                                ...
# 119477              1.0  @anthonyzenkus Eviction moratorium destroyed s...
# 119585              1.0  @Politics_Polls @ABC @washingtonpost Oh ffs w ...
# 120413              1.0  @Josiahhaken @hardlynormal @CityRelief_ Unthin...
# 120550              1.0  @TheDetailConsp1 @Skrrt__Vonnegut @JeremyWard3...
# 121441              1.0  @itsJeffTiedrich While Americans were struggli...
#
#                  timestamp  PARENT_ID  TWEET_ID  root_node  \
# 101747 2021-08-03 01:02:45          0      1176          0
# 101748 2021-08-03 01:02:56          0      1259          0
# 101749 2021-08-03 01:03:47          0      1193          0
# 101754 2021-08-03 01:58:38          0      1069          0
# 101759 2021-08-03 02:30:31          0      1524          0
# ...                    ...        ...       ...        ...
# 119477 2021-11-16 12:56:56          0      1077          0
# 119585 2021-11-17 01:52:50          0      1271          0
# 120413 2021-11-21 02:33:00          0      1153          0
# 120550 2021-11-22 00:34:18          0      1340          0
# 121441 2021-11-27 16:16:27          0      1403          0
#
#                                                      text  \
# 101747  @CoriBush You are a leader. I just wanted to s...
# 101748  Why does @JoeBiden hate Americans? He wont act...
# 101749  @gregkellyusa @CoriBush She's sleeping on the ...
# 101754  @aplemkseriously @CoriBush @CoriBush knew July...
# 101759  @BillFOXLA @FoxNews I love how the only issue ...
# ...                                                   ...
# 119477  @anthonyzenkus Eviction moratorium destroyed s...
# 119585  @Politics_Polls @ABC @washingtonpost Oh ffs w ...
# 120413  @Josiahhaken @hardlynormal @CityRelief_ Unthin...
# 120550  @TheDetailConsp1 @Skrrt__Vonnegut @JeremyWard3...
# 121441  @itsJeffTiedrich While Americans were struggli...
#
#                                dict_target_emotion_stance  \
# 101747  [{'target': '@CoriBush', 'emotion': 'neutral',...
# 101748  [{'target': '@JoeBiden', 'emotion': 'anger', '...
# 101749  [{'target': '@CoriBush', 'emotion': 'disgust',...
# 101754  [{'target': '@CoriBush', 'emotion': 'neutral',...
# 101759  [{'target': '@BillFOXLA @FoxNews', 'emotion': ...
# ...                                                   ...
# 119477  [{'target': '@anthonyzenkus Eviction', 'emotio...
# 119585  [{'target': '@Politics_Polls @ABC @washingtonp...
# 120413  [{'target': '@Josiahhaken @hardlynormal', 'emo...
# 120550  [{'target': 'Afghanistan', 'emotion': 'neutral...
# 121441  [{'target': 'Joe Biden', 'emotion': 'neutral',...
#
#                                     target_emotion_stance  parent_id  \
# 101747  neutral emotion & FAVOR stance towards @CoriBu...          0
# 101748  anger emotion & AGAINST stance towards @JoeBid...          0
# 101749  disgust emotion & AGAINST stance towards @Cori...          0
# 101754  neutral emotion & FAVOR stance towards @CoriBu...          0
# 101759  neutral emotion & NEUTRAL stance towards @Bill...          0
# ...                                                   ...        ...
# 119477  neutral emotion & AGAINST stance towards @anth...          0
# 119585  anger emotion & AGAINST stance towards @Politi...          0
# 120413  neutral emotion & NEUTRAL stance towards @Josi...          0
# 120550  neutral emotion & NEUTRAL stance towards Afgha...          0
# 121441   neutral emotion & FAVOR stance towards Joe Biden          0
#
#         tweet_id         create_date  label   time_elapsed
# 101747      1176 2021-08-03 01:02:45      1       0.000000
# 101748      1259 2021-08-03 01:02:56      1       0.183333
# 101749      1193 2021-08-03 01:03:47      1       1.033333
# 101754      1069 2021-08-03 01:58:38      1      55.883333
# 101759      1524 2021-08-03 02:30:31      1      87.766667
# ...          ...                 ...    ...            ...
# 119477      1077 2021-11-16 12:56:56      1  151914.183333
# 119585      1271 2021-11-17 01:52:50      1  152690.083333
# 120413      1153 2021-11-21 02:33:00      1  158490.250000
# 120550      1340 2021-11-22 00:34:18      1  159811.550000
# 121441      1403 2021-11-27 16:16:27      1  167953.700000
#
# [385 rows x 16 columns]

# %%
df4[df4.dict_target_emotion_stance.isna()]
# Out:
# Empty DataFrame
# Columns: [author, statement, BinaryNumTarget, tweet, timestamp, PARENT_ID, TWEET_ID, root_node, text, dict_target_emotion_stance, target_emotion_stance, parent_id, tweet_id, create_date, label]
# Index: []

# %%
df4[df4.PARENT_ID==0].label.value_counts()
# Out:
# label
# 1    831
# 0    431
# Name: count, dtype: int64

# %%
pd.read_pickle('/content/drive/MyDrive/QE/Study2/TruthSeeker2023/truth_seeker_NER_clean.h5',compression='xz')
# Out:
#                                                      text  \
# 0       Says Donald Trump has "changed his mind" on ab...
# 1       @realDonaldTrump donald trump  I so wanted to ...
# 2       @hilljobee Ah, so eminent domain that Trump su...
# 3       Says Donald Trump "supports eminent domain" an...
# 4        Paid family leave for New York kicks in in 2018.
# ...                                                   ...
# 122799  @Kokomothegreat TWO VOTES PER PRECINCT....I HA...
# 122800  Remember when Republicans hammered Obama becau...
# 122801  @JohnCornyn Texas has the highest rate of unin...
# 122802  Corrupt Joe Biden and Obama, who spied on my c...
# 122803  @smiley_face50 @Tracy_Creates @JoeBiden Yes it...
#
#                                dict_target_emotion_stance  \
# 0       [{'target': 'Donald Trump', 'emotion': 'neutra...
# 1       [{'target': '@realDonaldTrump donald trump', '...
# 2       [{'target': 'Trump', 'emotion': 'neutral', 'st...
# 3       [{'target': 'Donald Trump', 'emotion': 'neutra...
# 4       [{'target': 'New York', 'emotion': 'neutral', ...
# ...                                                   ...
# 122799  [{'target': 'TWEETS', 'emotion': 'neutral', 's...
# 122800  [{'target': 'Obama', 'emotion': 'neutral', 'st...
# 122801  [{'target': 'Texas', 'emotion': 'neutral', 'st...
# 122802  [{'target': 'Joe Biden', 'emotion': 'neutral',...
# 122803  [{'target': '', 'emotion': 'neutral', 'stance'...
#
#                                     target_emotion_stance  \
# 0       neutral emotion & AGAINST stance towards Donal...
# 1       neutral emotion & AGAINST stance towards @real...
# 2       neutral emotion & AGAINST stance towards Trump...
# 3       neutral emotion & NEUTRAL stance towards Donal...
# 4       neutral emotion & NEUTRAL stance towards New York
# ...                                                   ...
# 122799    neutral emotion & NEUTRAL stance towards TWEETS
# 122800  neutral emotion & AGAINST stance towards Obama...
# 122801     neutral emotion & AGAINST stance towards Texas
# 122802  neutral emotion & AGAINST stance towards Joe B...
# 122803          neutral emotion & NEUTRAL stance towards
#
#                            create_date  parent_id  tweet_id  root_node  label
# 0       Fri Apr 01 00:28:51 +0000 2016          0       359        359      1
# 1       Fri Apr 01 00:28:51 +0000 2016        359     45031        359      1
# 2       Fri Apr 01 00:52:15 +0000 2016        342     42069        342      1
# 3       Fri Apr 01 00:52:15 +0000 2016          0       342        342      1
# 4       Fri Apr 01 01:36:18 +0000 2016        123     16027        123      1
# ...                                ...        ...       ...        ...    ...
# 122799  Wed Sep 30 23:16:07 +0000 2020         27      6643         27      1
# 122800  Wed Sep 30 23:16:49 +0000 2020        331     39777        331      1
# 122801  Wed Sep 30 23:44:29 +0000 2020        540     70636        540      1
# 122802  Wed Sep 30 23:55:01 +0000 2020        989    125851        989      0
# 122803  Wed Sep 30 23:57:36 +0000 2020        970    122358        970      0
#
# [122804 rows x 8 columns]

# %%
df4.to_pickle('/content/drive/MyDrive/QE/Study2/TruthSeeker2023/truth_seeker_NER_clean2.h5',compression='xz')

# %%
# df2.to_pickle('/content/drive/MyDrive/QE/Study2/TruthSeeker2023/truth_seeker_NER_clean.h5',compression='xz')

# %%
#df.to_pickle('/content/drive/MyDrive/QE/Study2/TruthSeeker2023/truth_seeker_NER_emotion_stance.h5',compression='xz')
