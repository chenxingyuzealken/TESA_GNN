# %%
# from huggingface_hub import notebook_login

# notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
#source: https://github.com/huggingface/peft/blob/main/examples/int8_training/Finetune_flan_t5_large_bnb_peft.ipynb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -q bitsandbytes datasets accelerate
# !pip install transformers
# !pip install -q git+https://github.com/huggingface/transformers.git@main git+https://github.com/huggingface/peft.git@main
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 14.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 43.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 32.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.38.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.2.2)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#   Building wheel for peft (pyproject.toml) ... done

# %%
# Select CUDA device index
import os
import torch

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

from datasets import load_dataset
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

model_name = "google/flan-t5-large"

model = AutoModelForSeq2SeqLM.from_pretrained(model_name, load_in_8bit=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.54k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %% [markdown]
# # **Prepare model for training**
# Some pre-processing needs to be done before training such an int8 model using peft, therefore let's import an utiliy function prepare_model_for_int8_training that will:
#
# Casts all the non int8 modules to full precision (fp32) for stability
# Add a forward_hook to the input embedding layer to enable gradient computation of the input hidden states
# Enable gradient checkpointing for more memory-efficient training

# %%
from peft import prepare_model_for_int8_training

model = prepare_model_for_int8_training(model)
# Out:
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:145: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(

# %% [markdown]
# Load your PeftModel
# Here we will use LoRA (Low-Rank Adaptators) to train our model

# %%
from peft import LoraConfig, get_peft_model, TaskType


def print_trainable_parameters(model):
    """
    Prints the number of trainable parameters in the model.
    """
    trainable_params = 0
    all_param = 0
    for _, param in model.named_parameters():
        all_param += param.numel()
        if param.requires_grad:
            trainable_params += param.numel()
    print(
        f"trainable params: {trainable_params} || all params: {all_param} || trainable%: {100 * trainable_params / all_param}"
    )


lora_config = LoraConfig(
    r=16, lora_alpha=32, target_modules=["q", "v"], lora_dropout=0.05, bias="none", task_type="SEQ_2_SEQ_LM"
)


model = get_peft_model(model, lora_config)
print_trainable_parameters(model)
# Out:
# trainable params: 4718592 || all params: 787868672 || trainable%: 0.5989059049678777

# %% [markdown]
# # Load and process data

# %%
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

import torch
from tqdm import tqdm
tqdm.pandas()
from sklearn.utils import resample

import numpy as np
import os

import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rc

from sklearn.model_selection import train_test_split

from datasets import Dataset

# %% [markdown]
# Label df

# %%
import torch
from peft import PeftModel, PeftConfig
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer

peft_model_id = "kenchenxingyu/flan-large-lora-stance-human7"
config = PeftConfig.from_pretrained(peft_model_id)

model = AutoModelForSeq2SeqLM.from_pretrained(config.base_model_name_or_path, torch_dtype="auto", device_map="auto")
tokenizer = AutoTokenizer.from_pretrained(config.base_model_name_or_path)

# Load the Lora model
model = PeftModel.from_pretrained(model, peft_model_id)
# Out:
# adapter_config.json:   0%|          | 0.00/589 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/18.9M [00:00<?, ?B/s]

# %%
origin_data = pd.read_pickle('/content/drive/MyDrive/QE/Study2/FibVID-v0.0.1/dataset/origin_data_NER_emotion_stance.h5',compression='xz')
origin_data['source_text'] = "Classify stance towards the target:" + origin_data['target'].apply(lambda x: str(x)) + " in the text: "  + origin_data['post_text']
origin_data
# Out:
#                    create_date             tweet_id  similarity  like_count  \
# 0     2020-07-28T14:04:36.000Z  1288113129889517578    0.000000        2823
# 1     2020-07-28T14:04:36.000Z  1288113129889517578    0.000000        2823
# 2     2020-07-27T21:05:06.000Z  1287856562200088581    0.000000         822
# 3     2020-07-27T21:05:06.000Z  1287856562200088581    0.000000         822
# 4     2020-07-27T21:05:06.000Z  1287856562200088581    0.000000         822
# ...                        ...                  ...         ...         ...
# 3777  2020-12-05T11:19:16.000Z  1335181945635004417    0.659882        1436
# 3778  2020-12-20T20:31:55.000Z  1340756841454850049    0.390273      171932
# 3779  2020-05-08T17:16:17.000Z  1258807951164239873    0.856750         283
# 3780  2020-05-08T17:16:17.000Z  1258807951164239873    0.856750         283
# 3781  2020-05-08T17:16:17.000Z  1258807951164239873    0.856750         283
#
#       retweet_count                                          post_text  \
# 0              1050  The latest round of testing from the Miami Mar...
# 1              1050  The latest round of testing from the Miami Mar...
# 2               428  “It feels like we’re alone,” Hialeah, FL, Mayo...
# 3               428  “It feels like we’re alone,” Hialeah, FL, Mayo...
# 4               428  “It feels like we’re alone,” Hialeah, FL, Mayo...
# ...             ...                                                ...
# 3777            180  We broke the news on #OutLoudWithGiannoCaldwel...
# 3778           2654  I see your tweets and I’m trying to double and...
# 3779            205  A 2020 peer-reviewed study published in the jo...
# 3780            205  A 2020 peer-reviewed study published in the jo...
# 3781            205  A 2020 peer-reviewed study published in the jo...
#
#       claim_number  group                    hashtag  tweet_user  \
# 0                0      1                        NaN       85952
# 1                0      1                        NaN       85952
# 2                0      1                        NaN       78787
# 3                0      1                        NaN       78787
# 4                0      1                        NaN       78787
# ...            ...    ...                        ...         ...
# 3777           298      1  OutLoudWithGiannoCaldwell       73973
# 3778           298      1                        NaN       75482
# 3779           299      1                        NaN      103443
# 3780           299      1                        NaN      103443
# 3781           299      1                        NaN      103443
#
#                                                     NER target_type  \
# 0                              (the Miami Marlins, ORG)         ORG
# 1                                           (ESPN, ORG)         ORG
# 2                                        (Hialeah, GPE)         GPE
# 3                                             (FL, GPE)         GPE
# 4                            (Carlos Hernandez, PERSON)      PERSON
# ...                                                 ...         ...
# 3777  (Gianno Caldwell.https://t.co/aAKVBelRJO, PERSON)      PERSON
# 3778                             (MrBeast Burgers, ORG)         ORG
# 3779                                          (US, GPE)         GPE
# 3780                                         (DoD, ORG)         ORG
# 3781                                    (Mikovits, ORG)         ORG
#
#                                        target  target_filter  \
# 0                           the Miami Marlins           True
# 1                                        ESPN           True
# 2                                     Hialeah           True
# 3                                          FL           True
# 4                            Carlos Hernandez           True
# ...                                       ...            ...
# 3777  Gianno Caldwell.https://t.co/aAKVBelRJO           True
# 3778                          MrBeast Burgers           True
# 3779                                       US           True
# 3780                                      DoD           True
# 3781                                 Mikovits           True
#
#                                             source_text flan_emotion_pred  \
# 0     Classify stance towards the target:the Miami M...                 4
# 1     Classify stance towards the target:ESPN in the...                 4
# 2     Classify stance towards the target:Hialeah in ...                 4
# 3     Classify stance towards the target:FL in the t...                 4
# 4     Classify stance towards the target:Carlos Hern...                 4
# ...                                                 ...               ...
# 3777  Classify stance towards the target:Gianno Cald...                 4
# 3778  Classify stance towards the target:MrBeast Bur...                 4
# 3779  Classify stance towards the target:US in the t...                 4
# 3780  Classify stance towards the target:DoD in the ...                 4
# 3781  Classify stance towards the target:Mikovits in...                 4
#
#       emotion flan_stance   stance
# 0     neutral           0  AGAINST
# 1     neutral           1  NEUTRAL
# 2     neutral           1  NEUTRAL
# 3     neutral           1  NEUTRAL
# 4     neutral           1  NEUTRAL
# ...       ...         ...      ...
# 3777  neutral           2    FAVOR
# 3778  neutral           2    FAVOR
# 3779  neutral           1  NEUTRAL
# 3780  neutral           1  NEUTRAL
# 3781  neutral           1  NEUTRAL
#
# [3782 rows x 19 columns]

# %%
from IPython.display import clear_output

df = origin_data

samples_number = len(df)
progress_bar = tqdm(range(samples_number))
predictions_list = []


for i in range(samples_number):
    input_text = df['source_text'][i]

    if len(input_text.split()) < 1000:
        inputs = tokenizer(input_text, max_length=512, padding="max_length", truncation=True,return_tensors="pt")
    else:
        inputs = tokenizer(input_text, padding='max_length', max_length=512, truncation=True, return_tensors='pt')

    # Move the input tensors to the GPU if they are not already there
    #inputs = {key: value.to('cuda') for key, value in inputs.items()}
    #print(inputs)

    outputs = model.generate(input_ids=inputs['input_ids'].to('cuda'),
                             attention_mask=inputs['attention_mask'].to('cuda'),
                             max_length=10,
                             #num_beams=4,
                             #early_stopping=True
                             )
    del(inputs)
    torch.cuda.empty_cache()
    #gc.collect()

    prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
    predictions_list.append(prediction)
    #labels_list.append(test_df['label'][i])
    clear_output(wait=True)
    progress_bar.update(1)

origin_data['flan_stance'] = predictions_list

reverse_stance_mapping = {0:'AGAINST',
                  1:'NEUTRAL',
                  2:'FAVOR',
}

origin_data['stance'] = origin_data['flan_stance'].apply(lambda x: int(x)).map(reverse_stance_mapping)

origin_data.to_pickle('/content/drive/MyDrive/QE/Study2/FibVID-v0.0.1/dataset/origin_data_NER_emotion_stance.h5',compression='xz')
# Out:
# 100%|██████████| 3782/3782 [10:53<00:00,  6.39it/s]

# %%
origin_data.stance.value_counts(dropna=False)
# Out:
# NEUTRAL    2083
# AGAINST    1455
# FAVOR       244
# Name: stance, dtype: int64

# %%
news_claim = pd.read_pickle('/content/drive/MyDrive/QE/Study2/FibVID-v0.0.1/dataset/news_claim_NER_emotion_stance.h5',compression='xz')
news_claim['source_text'] = "Classify stance towards the target:" + news_claim['target'].apply(lambda x: str(x)) + " in the text: "  + news_claim['text']
news_claim
# Out:
#                                                    text      source  \
# 0     every election year has a disease  sars in 200...  politifact
# 1             obama ordered cia to train isis jihadists  politifact
# 2             obama ordered cia to train isis jihadists  politifact
# 3     says george soros said, im going to bring down...  politifact
# 4     says george soros said, im going to bring down...  politifact
# ...                                                 ...         ...
# 1604  nancy pelosi may have just committed a violati...  politifact
# 1605  says donald trump tweeted, i have it on good a...  politifact
# 1606  says donald trump tweeted, i have it on good a...  politifact
# 1607  says eight iowa counties have more adults regi...  politifact
# 1608  says kobe bryants wife recorded her suicide af...  politifact
#
#       claim_num  group                       NER target_type  \
# 0             1      1            (zika, PERSON)      PERSON
# 1             2      3           (obama, PERSON)      PERSON
# 2             2      3                (cia, ORG)         ORG
# 3             3      3    (george soros, PERSON)      PERSON
# 4             3      3  (the united states, GPE)         GPE
# ...         ...    ...                       ...         ...
# 1604       1349      3          (trumps, PERSON)      PERSON
# 1605       1350      3    (donald trump, PERSON)      PERSON
# 1606       1350      3                (dnc, ORG)         ORG
# 1607       1351      3               (iowa, GPE)         GPE
# 1608       1352      3    (kobe bryants, PERSON)      PERSON
#
#                  target  target_filter  \
# 0                  zika           True
# 1                 obama           True
# 2                   cia           True
# 3          george soros           True
# 4     the united states           True
# ...                 ...            ...
# 1604             trumps           True
# 1605       donald trump           True
# 1606                dnc           True
# 1607               iowa           True
# 1608       kobe bryants           True
#
#                                             source_text flan_emotion_pred  \
# 0     Classify stance towards the target:zika in the...                 4
# 1     Classify stance towards the target:obama in th...                 4
# 2     Classify stance towards the target:cia in the ...                 4
# 3     Classify stance towards the target:george soro...                 4
# 4     Classify stance towards the target:the united ...                 4
# ...                                                 ...               ...
# 1604  Classify stance towards the target:trumps in t...                 4
# 1605  Classify stance towards the target:donald trum...                 4
# 1606  Classify stance towards the target:dnc in the ...                 4
# 1607  Classify stance towards the target:iowa in the...                 4
# 1608  Classify stance towards the target:kobe bryant...                 4
#
#       emotion
# 0     neutral
# 1     neutral
# 2     neutral
# 3     neutral
# 4     neutral
# ...       ...
# 1604  neutral
# 1605  neutral
# 1606  neutral
# 1607  neutral
# 1608  neutral
#
# [1609 rows x 11 columns]

# %%
from IPython.display import clear_output

df = news_claim

samples_number = len(df)
progress_bar = tqdm(range(samples_number))
predictions_list = []


for i in range(samples_number):
    input_text = df['source_text'][i]

    if len(input_text.split()) < 1000:
        inputs = tokenizer(input_text, max_length=512, padding="max_length", truncation=True,return_tensors="pt")
    else:
        inputs = tokenizer(input_text, padding='max_length', max_length=512, truncation=True, return_tensors='pt')

    # Move the input tensors to the GPU if they are not already there
    #inputs = {key: value.to('cuda') for key, value in inputs.items()}
    #print(inputs)

    outputs = model.generate(input_ids=inputs['input_ids'].to('cuda'),
                             attention_mask=inputs['attention_mask'].to('cuda'),
                             max_length=10,
                             #num_beams=4,
                             #early_stopping=True
                             )
    del(inputs)
    torch.cuda.empty_cache()
    #gc.collect()

    prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
    predictions_list.append(prediction)
    #labels_list.append(test_df['label'][i])
    clear_output(wait=True)
    progress_bar.update(1)

news_claim['flan_stance'] = predictions_list

reverse_stance_mapping = {0:'AGAINST',
                  1:'NEUTRAL',
                  2:'FAVOR',
}

news_claim['stance'] = news_claim['flan_stance'].apply(lambda x: int(x)).map(reverse_stance_mapping)

news_claim.to_pickle('/content/drive/MyDrive/QE/Study2/FibVID-v0.0.1/dataset/news_claim_NER_emotion_stance.h5',compression='xz')
# Out:
# 100%|██████████| 1609/1609 [04:27<00:00,  5.81it/s]

# %%
news_claim.stance.value_counts(dropna=False)
# Out:
# NEUTRAL    941
# AGAINST    572
# FAVOR       96
# Name: stance, dtype: int64

# %%
claim_propagation = pd.read_pickle('/content/drive/MyDrive/QE/Study2/FibVID-v0.0.1/dataset/claim_propagation_data_NER_emotion_stance.h5',compression='xz')
claim_propagation['source_text'] = "Classify stance towards the target:" + claim_propagation['target'].apply(lambda x: str(x)) + " in the text: "  + claim_propagation['post_text']
claim_propagation
# Out:
#         tweet_user             tweet_id  like_count  depth  parent_user  \
# 0               64  1260590991641362436         301      0            0
# 1              135  1288771853822103552         194      0            0
# 2              135  1288771853822103552         194      0            0
# 3              290  1251209120528637952        7650      0            0
# 4              290  1251209120528637952        7650      0            0
# ...            ...                  ...         ...    ...          ...
# 289116      144736  1235937681047080960           0      1       106463
# 289117      144738  1242264347025571842           0      1        93248
# 289118      144739  1234597235746394118           0      1        56172
# 289119      144739  1234597235746394118           0      1        56172
# 289120      144740  1283521698285998082           0      1        37059
#
#                      create_date            parent_id  retweet_count  \
# 0       2020-05-13T15:21:27.000Z                    0            113
# 1       2020-07-30T09:42:08.000Z                    0             99
# 2       2020-07-30T09:42:08.000Z                    0             99
# 3       2020-04-17T18:01:15.000Z                    0           4279
# 4       2020-04-17T18:01:15.000Z                    0           4279
# ...                          ...                  ...            ...
# 289116  2020-03-06T14:38:00.000Z  1235932698688053249              0
# 289117  2020-03-24T01:37:55.000Z  1242257594540056576              1
# 289118  2020-03-02T21:51:33.000Z  1234592892896923652              0
# 289119  2020-03-02T21:51:33.000Z  1234592892896923652              0
# 289120  2020-07-15T21:59:54.000Z  1283488682863996929              0
#
#                                                 post_text  claim_number  \
# 0       So you left a 69 page guidebook but no PPE or ...           141
# 1       More tales from the NHS frontline are emerging...           138
# 2       More tales from the NHS frontline are emerging...           138
# 3       DEVELOPING: A crowd of protesters could be see...            30
# 4       DEVELOPING: A crowd of protesters could be see...            30
# ...                                                   ...           ...
# 289116  #WaterIsLife \nremember your vote matters, \nC...           229
# 289117  NO @GOP should even entertain this anti-Americ...            96
# 289118  I assume if you win it will the begging of the...           173
# 289119  I assume if you win it will the begging of the...           173
# 289120  @RealMattyMorse @EigenmannSarah @LtGovFlanagan...            98
#
#         group                                     hashtag  \
# 0           1                                         NaN
# 1           0                                         NaN
# 2           0                                         NaN
# 3           0                                         NaN
# 4           0                                         NaN
# ...       ...                                         ...
# 289116      2  WaterIsLife#WhenWeAllVote#FlintWaterCrisis
# 289117      0                                         NaN
# 289118      3                                         NaN
# 289119      3                                         NaN
# 289120      1                                         NaN
#
#                                            NER target_type  \
# 0                                   (PPE, ORG)         ORG
# 1                                   (NHS, ORG)         ORG
# 2                            (wards &amp, ORG)         ORG
# 3                        (@GovTimWalz, PERSON)      PERSON
# 4                           (Minnesotans, ORG)         ORG
# ...                                        ...         ...
# 289116                                     NaN
# 289117  (@realDonaldTrump  @senatemajldr, ORG)         ORG
# 289118             (AMERICAN IMPERIALISM, ORG)         ORG
# 289119          (https://t.co/JFI65K1n1U, ORG)         ORG
# 289120                   (@GovTimWalz, PERSON)      PERSON
#
#                                  target  target_filter  \
# 0                                   PPE           True
# 1                                   NHS           True
# 2                            wards &amp           True
# 3                           @GovTimWalz           True
# 4                           Minnesotans           True
# ...                                 ...            ...
# 289116                               []           True
# 289117  @realDonaldTrump  @senatemajldr           True
# 289118             AMERICAN IMPERIALISM           True
# 289119          https://t.co/JFI65K1n1U           True
# 289120                      @GovTimWalz           True
#
#                                               source_text flan_emotion_pred  \
# 0       Classify stance towards the target:PPE in the ...                 4
# 1       Classify stance towards the target:NHS in the ...                 4
# 2       Classify stance towards the target:wards &amp ...                 4
# 3       Classify stance towards the target:@GovTimWalz...                 4
# 4       Classify stance towards the target:Minnesotans...                 4
# ...                                                   ...               ...
# 289116  Classify stance towards the target:[] in the t...                 4
# 289117  Classify stance towards the target:@realDonald...                 4
# 289118  Classify stance towards the target:AMERICAN IM...                 4
# 289119  Classify stance towards the target:https://t.c...                 4
# 289120  Classify stance towards the target:@GovTimWalz...                 4
#
#         emotion
# 0       neutral
# 1       neutral
# 2       neutral
# 3       neutral
# 4       neutral
# ...         ...
# 289116  neutral
# 289117  neutral
# 289118  neutral
# 289119  neutral
# 289120  neutral
#
# [289121 rows x 19 columns]

# %%
from IPython.display import clear_output

df = claim_propagation

samples_number = len(df)
progress_bar = tqdm(range(samples_number))
predictions_list = []


for i in range(samples_number):
    input_text = df['source_text'][i]

    if len(input_text.split()) < 1000:
        inputs = tokenizer(input_text, max_length=512, padding="max_length", truncation=True,return_tensors="pt")
    else:
        inputs = tokenizer(input_text, padding='max_length', max_length=512, truncation=True, return_tensors='pt')

    # Move the input tensors to the GPU if they are not already there
    #inputs = {key: value.to('cuda') for key, value in inputs.items()}
    #print(inputs)

    outputs = model.generate(input_ids=inputs['input_ids'].to('cuda'),
                             attention_mask=inputs['attention_mask'].to('cuda'),
                             max_length=10,
                             #num_beams=4,
                             #early_stopping=True
                             )
    del(inputs)
    torch.cuda.empty_cache()
    #gc.collect()

    prediction = tokenizer.decode(outputs[0], skip_special_tokens=True)
    predictions_list.append(prediction)
    #labels_list.append(test_df['label'][i])
    clear_output(wait=True)
    progress_bar.update(1)

claim_propagation['flan_stance'] = predictions_list

reverse_stance_mapping = {0:'AGAINST',
                  1:'NEUTRAL',
                  2:'FAVOR',
}

claim_propagation['stance'] = claim_propagation['flan_stance'].apply(lambda x: int(x)).map(reverse_stance_mapping)
# Out:
# 100%|██████████| 289121/289121 [13:15:55<00:00,  6.59it/s]

# %%
claim_propagation.to_pickle('/content/drive/MyDrive/QE/Study2/FibVID-v0.0.1/dataset/claim_propagation_data_NER_emotion_stance.h5',compression='xz')

# %%
from google.colab import runtime
runtime.unassign()
